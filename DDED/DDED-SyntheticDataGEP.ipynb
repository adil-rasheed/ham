# %%
# === Cell 1: 2D Heat Equation Simulation and Save to CSV ===

import numpy as np
import pandas as pd

# Parameters
nx, ny = 50, 50
nt = 100
lx, ly = 1.0, 1.0
dx, dy = lx/nx, ly/ny
dt = 0.001
alpha = 0.01  # thermal diffusivity

x = np.linspace(0, lx, nx)
y = np.linspace(0, ly, ny)
t = np.arange(0, nt*dt, dt)

# Initialize temperature field
u = np.zeros((nx, ny, nt))
X, Y = np.meshgrid(x, y, indexing="ij")
u[:,:,0] = np.exp(-50*((X-0.5)**2 + (Y-0.5)**2))  # Gaussian IC

# Time stepping (explicit FTCS)
for k in range(0, nt-1):
    u_xx = (np.roll(u[:,:,k], -1, axis=0) - 2*u[:,:,k] + np.roll(u[:,:,k], 1, axis=0)) / dx**2
    u_yy = (np.roll(u[:,:,k], -1, axis=1) - 2*u[:,:,k] + np.roll(u[:,:,k], 1, axis=1)) / dy**2
    u[:,:,k+1] = u[:,:,k] + alpha * dt * (u_xx + u_yy)

# Save to CSV
X, Y, T = np.meshgrid(x, y, t, indexing="ij")
df = pd.DataFrame({
    "x": X.ravel(),
    "y": Y.ravel(),
    "t": T.ravel(),
    "u": u.ravel()
})
df.to_csv("rawdata.csv", index=False)
print("Saved rawdata.csv with shape:", df.shape)
# Out:
# Saved rawdata.csv with shape: (250000, 4)

# %%
# === Cell 2: Load Data ===
df = pd.read_csv("rawdata.csv")
print(df.head())

x = np.unique(df["x"].values)
y = np.unique(df["y"].values)
t = np.unique(df["t"].values)

u = df["u"].values.reshape(len(x), len(y), len(t))
print("u.shape =", u.shape)
# Out:
#      x    y      t             u
# 0  0.0  0.0  0.000  1.388794e-11
# 1  0.0  0.0  0.001  1.508033e-11
# 2  0.0  0.0  0.002  1.634005e-11
# 3  0.0  0.0  0.003  1.766995e-11
# 4  0.0  0.0  0.004  1.907300e-11
# u.shape = (50, 50, 100)

# %%
# === Cell 3: Derivatives (central differences, higher order) ===

nt, nx, ny = len(t), len(x), len(y)

u_t   = np.zeros_like(u)
u_2t  = np.zeros_like(u)
u_x   = np.zeros_like(u)
u_2x  = np.zeros_like(u)
u_3x  = np.zeros_like(u)
u_y   = np.zeros_like(u)
u_2y  = np.zeros_like(u)
u_3y  = np.zeros_like(u)

for k in range(1, nt-1):
    for i in range(2, nx-2):
        for j in range(2, ny-2):
            # Time derivatives
            u_t[i,j,k]  = (u[i,j,k+1] - u[i,j,k-1]) / (2*dt)
            u_2t[i,j,k] = (u[i,j,k+1] - 2*u[i,j,k] + u[i,j,k-1]) / (dt**2)

            # Space derivatives (x)
            u_x[i,j,k]  = (u[i+1,j,k] - u[i-1,j,k]) / (2*dx)
            u_2x[i,j,k] = (u[i+1,j,k] - 2*u[i,j,k] + u[i-1,j,k]) / (dx**2)
            u_3x[i,j,k] = (u[i+2,j,k] - 2*u[i+1,j,k] + 2*u[i-1,j,k] - u[i-2,j,k]) / (2*dx**3)

            # Space derivatives (y)
            u_y[i,j,k]  = (u[i,j+1,k] - u[i,j-1,k]) / (2*dy)
            u_2y[i,j,k] = (u[i,j+1,k] - 2*u[i,j,k] + u[i,j-1,k]) / (dy**2)
            u_3y[i,j,k] = (u[i,j+2,k] - 2*u[i,j+1,k] + 2*u[i,j-1,k] - u[i,j-2,k]) / (2*dy**3)

print("Derivatives computed: u_t, u_2t, u_x, u_2x, u_3x, u_y, u_2y, u_3y")
# Out:
# Derivatives computed: u_t, u_2t, u_x, u_2x, u_3x, u_y, u_2y, u_3y

# %%
# Flatten features
Ut   = u_t.ravel()
U    = u.ravel()
Ux   = u_x.ravel()
U2x  = u_2x.ravel()
U3x  = u_3x.ravel()
Uy   = u_y.ravel()
U2y  = u_2y.ravel()
U3y  = u_3y.ravel()

X_features = np.column_stack([U, Ux, U2x, U3x, Uy, U2y, U3y])
feature_names = ["u", "u_x", "u_xx", "u_xxx", "u_y", "u_yy", "u_yyy"]

print("X_features shape:", X_features.shape)
print("Ut shape:", Ut.shape)
# Out:
# X_features shape: (250000, 7)
# Ut shape: (250000,)

# %%
# === Cell 5: Run PySR symbolic regression ===
# !pip install pysr

from pysr import PySRRegressor

model = PySRRegressor(
    niterations=40,
    unary_operators=[],
    binary_operators=["+", "-", "*", "/"],
    populations=20,
    model_selection="best",
    loss="loss(x, y) = (x - y)^2",
    verbosity=1,
)

model.fit(X_features, Ut)
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# c:\Users\adil\anaconda3\envs\ham\Lib\site-packages\pysr\sr.py:1036: FutureWarning: `loss` has been renamed to `elementwise_loss` in PySRRegressor. Please use that instead.
#   warnings.warn(
# c:\Users\adil\anaconda3\envs\ham\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# c:\Users\adil\anaconda3\envs\ham\Lib\site-packages\pysr\sr.py:2265: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://ai.damtp.cam.ac.uk/pysr/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 0.000e+00
# Progress: 0 / 800 total iterations (0.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.040e+02
# Progress: 29 / 800 total iterations (3.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = -1.2851e-05
# 3           2.104e-02  4.138e-01  y = 0.060323 - x₀
# 5           9.843e-03  3.798e-01  y = (x₅ * 0.024384) * x₀
# 7           8.218e-03  9.024e-02  y = ((x₀ * -1.9308) * x₀) + 0.052965
# 9           7.221e-03  6.466e-02  y = ((x₀ * (-1.1877 - x₀)) * x₀) - -0.049285
# 11          3.046e-06  3.885e+00  y = ((((x₅ + -0.17332) * -1.0001) - x₂) / 0.2316) * -0.002...
#                                       3191
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.080e+03
# Progress: 33 / 800 total iterations (4.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           2.104e-02  4.138e-01  y = 0.060323 - x₀
# 5           9.843e-03  3.798e-01  y = (x₅ * 0.024384) * x₀
# 7           8.218e-03  9.024e-02  y = ((x₀ * -1.9308) * x₀) + 0.052965
# 9           7.221e-03  6.466e-02  y = ((x₀ * (-1.1877 - x₀)) * x₀) - -0.049285
# 11          3.046e-06  3.885e+00  y = ((((x₅ + -0.17332) * -1.0001) - x₂) / 0.2316) * -0.002...
#                                       3191
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.920e+03
# Progress: 36 / 800 total iterations (4.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           2.104e-02  4.138e-01  y = 0.060323 - x₀
# 5           9.843e-03  3.798e-01  y = (x₅ * 0.024384) * x₀
# 7           8.218e-03  9.024e-02  y = ((x₀ * -1.9308) * x₀) + 0.052965
# 9           7.221e-03  6.466e-02  y = ((x₀ * (-1.1877 - x₀)) * x₀) - -0.049285
# 11          3.046e-06  3.885e+00  y = ((((x₅ + -0.17332) * -1.0001) - x₂) / 0.2316) * -0.002...
#                                       3191
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.750e+03
# Progress: 54 / 800 total iterations (6.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           2.104e-02  4.138e-01  y = 0.060323 - x₀
# 5           9.843e-03  3.798e-01  y = (x₅ * 0.024384) * x₀
# 7           8.218e-03  9.024e-02  y = ((x₀ * -1.9308) * x₀) + 0.052965
# 9           4.107e-03  3.468e-01  y = ((x₀ * -2.705) - x₀) * (x₀ - 0.37772)
# 11          3.046e-06  3.603e+00  y = ((((x₅ + -0.17332) * -1.0001) - x₂) / 0.2316) * -0.002...
#                                       3191
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.490e+03
# Progress: 73 / 800 total iterations (9.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           2.104e-02  4.138e-01  y = 0.060323 - x₀
# 5           9.843e-03  3.798e-01  y = (x₅ * 0.024384) * x₀
# 7           8.218e-03  9.024e-02  y = ((x₀ * -1.9308) * x₀) + 0.052965
# 9           4.107e-03  3.468e-01  y = ((x₀ * -2.705) - x₀) * (x₀ - 0.37772)
# 11          3.044e-06  3.604e+00  y = ((((-1.0001 * x₅) + -0.17332) - x₂) / 0.2316) * -0.002...
#                                       3191
# 13          4.588e-08  2.097e+00  y = ((((0.11571 * 0.09996) - x₂) + (-1.0001 * x₅)) / 0.231...
#                                       6) * -0.0023191
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.990e+03
# Progress: 74 / 800 total iterations (9.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           2.104e-02  4.138e-01  y = 0.060323 - x₀
# 5           9.843e-03  3.798e-01  y = (x₅ * 0.024384) * x₀
# 7           8.218e-03  9.024e-02  y = ((x₀ * -1.9308) * x₀) + 0.052965
# 9           3.203e-03  4.711e-01  y = (((x₅ * -0.82988) - x₂) / 0.17023) * -0.0023191
# 11          2.938e-06  3.497e+00  y = ((((x₅ * -1.0001) + 0.17019) - x₂) / 0.1706) * -0.0017...
#                                       085
# 13          4.588e-08  2.080e+00  y = ((((0.11571 * 0.09996) - x₂) + (-1.0001 * x₅)) / 0.231...
#                                       6) * -0.0023191
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.070e+03
# Progress: 87 / 800 total iterations (10.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           2.104e-02  4.138e-01  y = 0.060323 - x₀
# 5           9.843e-03  3.798e-01  y = (x₅ * 0.024384) * x₀
# 7           8.218e-03  9.024e-02  y = ((x₀ * -1.9308) * x₀) + 0.052965
# 9           1.262e-07  5.542e+00  y = (((x₅ * -1.0024) - x₂) / 0.2316) * -0.0023191
# 11          3.281e-08  6.737e-01  y = (((x₅ * -1.0001) + (-0.0023185 - x₂)) * -0.0023214) / ...
#                                       0.23183
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.120e+03
# Progress: 95 / 800 total iterations (11.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           2.104e-02  4.138e-01  y = 0.060323 - x₀
# 5           9.843e-03  3.798e-01  y = (x₅ * 0.024384) * x₀
# 7           8.218e-03  9.024e-02  y = ((x₀ * -1.9308) * x₀) + 0.052965
# 9           3.267e-08  6.218e+00  y = (((0.0019661 - x₅) - x₂) / 0.1706) * -0.0017085
# 13          3.267e-08  4.023e-07  y = (-0.0017085 * ((0.0019661 - ((x₀ - x₀) + x₅)) - x₂)) /...
#                                        0.1706
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.170e+03
# Progress: 104 / 800 total iterations (13.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           2.104e-02  4.138e-01  y = 0.060323 - x₀
# 5           9.843e-03  3.798e-01  y = (x₅ * 0.024384) * x₀
# 7           8.218e-03  9.024e-02  y = ((x₀ * -1.9308) * x₀) + 0.052965
# 9           3.228e-08  6.224e+00  y = (((x₅ * -1.0001) - x₂) * -0.0023214) / 0.23183
# 13          3.226e-08  2.020e-04  y = ((((-0.0039403 - x₂) + (x₅ * -1.0001)) * -0.0023311) +...
#                                        -9.1657e-06) / 0.23279
# 15          1.733e-08  3.107e-01  y = (((x₅ * -0.99899) - x₂) + (((x₄ - -1.0001) * x₄) * -0....
#                                       0029106)) * -0.010021
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.220e+03
# Progress: 116 / 800 total iterations (14.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           9.843e-03  2.428e-01  y = (x₅ * 0.024384) * x₀
# 7           8.218e-03  9.024e-02  y = ((x₀ * -1.9308) * x₀) + 0.052965
# 9           3.222e-08  6.225e+00  y = (((x₅ * -1) - x₂) + 0.0002828) * -0.010014
# 13          3.094e-08  1.011e-02  y = (((0.0019661 - (x₅ + (x₀ * 0.0065197))) - x₂) * -0.001...
#                                       7085) / 0.1706
# 15          1.733e-08  2.899e-01  y = (((x₅ * -0.99899) - x₂) + (((x₄ - -1.0001) * x₄) * -0....
#                                       0029106)) * -0.010021
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.090e+03
# Progress: 126 / 800 total iterations (15.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           9.788e-03  2.456e-01  y = (x₀ * 0.023493) * x₂
# 7           3.973e-08  6.207e+00  y = -0.010021 * ((x₅ * -0.99899) - x₂)
# 9           3.222e-08  1.048e-01  y = (((x₅ * -1) - x₂) + 0.0002828) * -0.010014
# 13          3.094e-08  1.011e-02  y = (((0.0019661 - (x₅ + (x₀ * 0.0065197))) - x₂) * -0.001...
#                                       7085) / 0.1706
# 15          1.733e-08  2.899e-01  y = (((x₅ * -0.99899) - x₂) + (((x₄ - -1.0001) * x₄) * -0....
#                                       0029106)) * -0.010021
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.900e+03
# Progress: 140 / 800 total iterations (17.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           9.788e-03  2.456e-01  y = (x₀ * 0.023493) * x₂
# 7           3.221e-08  6.312e+00  y = ((x₅ * -1) - x₂) * -0.010014
# 13          3.094e-08  6.697e-03  y = (((0.0019661 - (x₅ + (x₀ * 0.0065197))) - x₂) * -0.001...
#                                       7085) / 0.1706
# 15          1.733e-08  2.899e-01  y = (((x₅ * -0.99899) - x₂) + (((x₄ - -1.0001) * x₄) * -0....
#                                       0029106)) * -0.010021
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.260e+03
# Progress: 159 / 800 total iterations (19.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           5.411e-03  5.420e-01  y = (x₅ + x₂) * 0.013372
# 7           3.221e-08  6.016e+00  y = ((x₅ * -1) - x₂) * -0.010014
# 13          3.094e-08  6.697e-03  y = (((0.0019661 - (x₅ + (x₀ * 0.0065197))) - x₂) * -0.001...
#                                       7085) / 0.1706
# 15          1.655e-08  3.129e-01  y = ((((x₄ + 0.51822) * x₄) * -0.0029106) + ((x₅ * -0.9989...
#                                       9) - x₂)) * -0.010021
# 17          1.633e-08  6.746e-03  y = (((x₅ * -0.99899) - x₂) + ((((x₄ - -1.0001) * x₄) - 0....
#                                       6328) * -0.0029106)) * -0.010021
# 19          1.504e-08  4.105e-02  y = (((x₅ * -0.99899) - x₂) + (((x₄ - -1.0001) * ((x₄ - 0....
#                                       6328) + -0.67014)) * -0.0029106)) * -0.010021
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.160e+03
# Progress: 181 / 800 total iterations (22.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           5.411e-03  5.420e-01  y = (x₅ + x₂) * 0.013372
# 7           3.221e-08  6.016e+00  y = ((x₅ * -1) - x₂) * -0.010014
# 13          1.626e-08  1.139e-01  y = ((x₄ * (x₄ * -0.0029106)) + ((x₅ * -0.99899) - x₂)) * ...
#                                       -0.010021
# 15          1.503e-08  3.944e-02  y = (((-0.99899 * x₅) - x₂) + (((x₄ * x₄) - 0.92316) * -0....
#                                       0029106)) * -0.010021
# 17          1.387e-08  4.028e-02  y = -0.010021 * (((-0.99899 * x₅) - x₂) + (((-0.67014 + (x...
#                                       ₄ * x₄)) * 1.4859) * -0.0029106))
# 19          1.331e-08  2.039e-02  y = -0.010021 * (((x₅ * -0.99899) - x₂) + (((-0.67014 + (x...
#                                       ₄ * (x₄ * 1.4859))) - 0.88855) * -0.0029106))
# 21          1.238e-08  3.635e-02  y = (((x₅ * -0.99885) - x₂) + ((((((x₄ * x₄) + -0.67014) *...
#                                        1.4859) + x₀) - 0.88855) * -0.0028826)) * -0.010023
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.420e+03
# Progress: 187 / 800 total iterations (23.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           5.411e-03  5.420e-01  y = (x₅ + x₂) * 0.013372
# 7           3.221e-08  6.016e+00  y = ((x₅ * -1) - x₂) * -0.010014
# 13          1.626e-08  1.139e-01  y = ((x₄ * (x₄ * -0.0029106)) + ((x₅ * -0.99899) - x₂)) * ...
#                                       -0.010021
# 15          1.503e-08  3.944e-02  y = (((-0.99899 * x₅) - x₂) + (((x₄ * x₄) - 0.92316) * -0....
#                                       0029106)) * -0.010021
# 17          1.360e-08  4.985e-02  y = ((((x₄ - 0.6328) * -0.0040788) * (x₄ - -0.98672)) + ((...
#                                       x₅ * -0.99907) - x₂)) * -0.010021
# 19          1.331e-08  1.082e-02  y = -0.010021 * (((x₅ * -0.99899) - x₂) + (((-0.67014 + (x...
#                                       ₄ * (x₄ * 1.4859))) - 0.88855) * -0.0029106))
# 21          1.238e-08  3.635e-02  y = (((x₅ * -0.99885) - x₂) + ((((((x₄ * x₄) + -0.67014) *...
#                                        1.4859) + x₀) - 0.88855) * -0.0028826)) * -0.010023
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.620e+03
# Progress: 204 / 800 total iterations (25.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           8.763e-06  3.755e+00  y = (x₅ + x₂) * 0.0098793
# 7           3.221e-08  2.803e+00  y = ((x₅ * -1) - x₂) * -0.010014
# 9           3.221e-08  1.192e-05  y = ((0.31161 - (x₅ + 0.31163)) - x₂) * -0.010014
# 11          3.178e-08  6.781e-03  y = -0.010015 * ((-1.0001 * x₅) - (x₂ + (x₀ * 0.0034722)))
# 13          1.519e-08  3.690e-01  y = ((((x₄ * x₄) * -0.0036481) + (x₅ * -0.99899)) - x₂) * ...
#                                       -0.010022
# 15          1.302e-08  7.696e-02  y = ((((x₄ * x₄) + -0.67014) * -0.0042213) + ((x₅ * -0.998...
#                                       86) - x₂)) * -0.010023
# 19          1.243e-08  1.174e-02  y = (((x₅ * -0.99885) - x₂) + (((((x₄ * x₄) + -0.67014) * ...
#                                       1.4859) - 0.88855) * -0.0028826)) * -0.010023
# 21          1.238e-08  1.967e-03  y = (((x₅ * -0.99885) - x₂) + ((((((x₄ * x₄) + -0.67014) *...
#                                        1.4859) + x₀) - 0.88855) * -0.0028826)) * -0.010023
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.590e+03
# Progress: 209 / 800 total iterations (26.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           8.763e-06  3.755e+00  y = (x₅ + x₂) * 0.0098793
# 7           3.221e-08  2.803e+00  y = ((x₅ * -1) - x₂) * -0.010014
# 9           3.221e-08  1.979e-05  y = ((0.00035563 - (x₅ + 0.00039203)) - x₂) * -0.010014
# 11          3.178e-08  6.774e-03  y = -0.010015 * ((-1.0001 * x₅) - (x₂ + (x₀ * 0.0034722)))
# 13          1.519e-08  3.690e-01  y = ((((x₄ * x₄) * -0.0036481) + (x₅ * -0.99899)) - x₂) * ...
#                                       -0.010022
# 15          1.302e-08  7.696e-02  y = ((((x₄ * x₄) + -0.67014) * -0.0042213) + ((x₅ * -0.998...
#                                       86) - x₂)) * -0.010023
# 19          1.243e-08  1.174e-02  y = (((x₅ * -0.99885) - x₂) + (((((x₄ * x₄) + -0.67014) * ...
#                                       1.4859) - 0.88855) * -0.0028826)) * -0.010023
# 21          1.238e-08  1.967e-03  y = (((x₅ * -0.99885) - x₂) + ((((((x₄ * x₄) + -0.67014) *...
#                                        1.4859) + x₀) - 0.88855) * -0.0028826)) * -0.010023
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.600e+03
# Progress: 219 / 800 total iterations (27.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           8.763e-06  3.755e+00  y = (x₂ + x₅) * 0.0098793
# 7           3.221e-08  2.803e+00  y = (x₂ + (x₅ - -1.8144e-05)) * 0.010014
# 9           3.221e-08  6.795e-06  y = ((0.00035563 - (x₅ + 0.00039203)) - x₂) * -0.010014
# 11          3.178e-08  6.774e-03  y = -0.010015 * ((-1.0001 * x₅) - (x₂ + (x₀ * 0.0034722)))
# 13          1.519e-08  3.690e-01  y = ((((x₄ * x₄) * -0.0036481) + (x₅ * -0.99899)) - x₂) * ...
#                                       -0.010022
# 15          1.302e-08  7.696e-02  y = ((((x₄ * x₄) + -0.67014) * -0.0042213) + ((x₅ * -0.998...
#                                       86) - x₂)) * -0.010023
# 19          1.243e-08  1.174e-02  y = (((x₅ * -0.99885) - x₂) + (((((x₄ * x₄) + -0.67014) * ...
#                                       1.4859) - 0.88855) * -0.0028826)) * -0.010023
# 21          1.238e-08  1.967e-03  y = (((x₅ * -0.99885) - x₂) + ((((((x₄ * x₄) + -0.67014) *...
#                                        1.4859) + x₀) - 0.88855) * -0.0028826)) * -0.010023
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.580e+03
# Progress: 225 / 800 total iterations (28.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           8.763e-06  3.755e+00  y = (x₂ + x₅) * 0.0098793
# 7           3.221e-08  2.803e+00  y = (x₂ + (x₅ - -1.8144e-05)) * 0.010014
# 9           3.221e-08  6.795e-06  y = ((0.00035563 - (x₅ + 0.00039203)) - x₂) * -0.010014
# 11          3.178e-08  6.774e-03  y = -0.010015 * ((-1.0001 * x₅) - (x₂ + (x₀ * 0.0034722)))
# 13          1.519e-08  3.690e-01  y = (((x₄ * (x₄ * -0.0036481)) + (x₅ * -0.99899)) - x₂) * ...
#                                       -0.010022
# 15          1.302e-08  7.696e-02  y = ((((x₄ * x₄) + -0.67014) * -0.0042213) + ((x₅ * -0.998...
#                                       86) - x₂)) * -0.010023
# 19          1.243e-08  1.174e-02  y = (((x₅ * -0.99885) - x₂) + (((((x₄ * x₄) + -0.67014) * ...
#                                       1.4859) - 0.88855) * -0.0028826)) * -0.010023
# 21          1.238e-08  1.967e-03  y = (((x₅ * -0.99885) - x₂) + ((((((x₄ * x₄) + -0.67014) *...
#                                        1.4859) + x₀) - 0.88855) * -0.0028826)) * -0.010023
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.710e+03
# Progress: 243 / 800 total iterations (30.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           8.763e-06  3.755e+00  y = (x₂ + x₅) * 0.0098793
# 7           3.221e-08  2.803e+00  y = (x₂ + (x₅ - -1.8144e-05)) * 0.010014
# 9           3.221e-08  6.795e-06  y = ((0.00035563 - (x₅ + 0.00039203)) - x₂) * -0.010014
# 11          2.190e-08  1.929e-01  y = ((x₀ * 0.00085928) + (x₅ * 0.010019)) - (x₂ * -0.01001...
#                                       9)
# 13          1.501e-08  1.889e-01  y = ((x₅ * -0.99895) - (x₂ + (x₄ * (x₄ * 0.0038985)))) * -...
#                                       0.010022
# 15          1.243e-08  9.447e-02  y = ((x₅ * -0.99885) + ((((x₄ * x₄) + -1.251) * -0.0042831...
#                                       ) - x₂)) * -0.010023
# 21          1.238e-08  6.556e-04  y = (((-0.99885 * x₅) - x₂) + (-0.0028826 * (((1.4859 * (x...
#                                       ₄ * x₄)) + (x₀ - 1.9187)) + -0.010023))) * -0.010023
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.190e+03
# Progress: 265 / 800 total iterations (33.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           8.763e-06  3.755e+00  y = (x₂ + x₅) * 0.0098793
# 7           3.221e-08  2.803e+00  y = (x₂ + (x₅ - -1.8144e-05)) * 0.010014
# 9           3.221e-08  6.795e-06  y = ((0.00035563 - (x₅ + 0.00039203)) - x₂) * -0.010014
# 11          2.190e-08  1.929e-01  y = ((x₀ * 0.00085928) + (x₅ * 0.010019)) - (x₂ * -0.01001...
#                                       9)
# 13          1.501e-08  1.889e-01  y = ((x₅ * -0.99895) - (x₂ + (x₄ * (x₄ * 0.0038985)))) * -...
#                                       0.010022
# 15          1.243e-08  9.447e-02  y = ((x₅ * -0.99885) + ((((x₄ * x₄) + -1.251) * -0.0042831...
#                                       ) - x₂)) * -0.010023
# 21          1.237e-08  7.015e-04  y = (((x₅ * -0.99885) - x₂) + (((((x₄ * x₄) * 1.4859) + x₀...
#                                       ) + (x₀ - 1.9187)) * -0.0028826)) * -0.010023
# 23          1.236e-08  6.352e-04  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + ((x₀ - 1.9187) + -0.010023))) * -0.0028504)) * -0.01002...
#                                       3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.210e+03
# Progress: 281 / 800 total iterations (35.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₂ + x₅) * 0.010014
# 7           3.221e-08  1.284e-05  y = (x₂ + (x₅ - -1.8144e-05)) * 0.010014
# 9           3.221e-08  6.616e-06  y = ((0.00035563 - (x₅ + 0.00039203)) - x₂) * -0.010014
# 11          2.190e-08  1.929e-01  y = ((x₀ * 0.00085928) + (x₅ * 0.010019)) - (x₂ * -0.01001...
#                                       9)
# 13          1.501e-08  1.889e-01  y = ((x₅ * -0.99895) - (x₂ + (x₄ * (x₄ * 0.0038985)))) * -...
#                                       0.010022
# 15          1.243e-08  9.447e-02  y = ((x₅ * -0.99885) + ((((x₄ * x₄) + -1.251) * -0.0042831...
#                                       ) - x₂)) * -0.010023
# 21          1.236e-08  9.015e-04  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + (x₀ - 1.9187))) * -0.0028504)) * -0.010023
# 23          1.236e-08  3.535e-05  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + ((x₀ - 1.9187) + -0.010023))) * -0.0028504)) * -0.01002...
#                                       3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.270e+03
# Progress: 296 / 800 total iterations (37.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₂ + x₅) * 0.010014
# 7           3.221e-08  1.284e-05  y = (x₂ + (x₅ - -1.8144e-05)) * 0.010014
# 9           3.221e-08  9.418e-06  y = 0.010014 * (x₂ + ((x₅ - -1.8144e-05) - -1.8144e-05))
# 11          2.190e-08  1.929e-01  y = ((x₀ * 0.00085928) + (x₅ * 0.010019)) - (x₂ * -0.01001...
#                                       9)
# 13          1.501e-08  1.889e-01  y = ((x₅ * -0.99895) - (x₂ + (x₄ * (x₄ * 0.0038985)))) * -...
#                                       0.010022
# 15          1.243e-08  9.447e-02  y = ((x₅ * -0.99885) + ((((x₄ * x₄) + -1.251) * -0.0042831...
#                                       ) - x₂)) * -0.010023
# 21          1.236e-08  9.015e-04  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + (x₀ - 1.9187))) * -0.0028504)) * -0.010023
# 23          1.236e-08  3.535e-05  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + ((x₀ - 1.9187) + -0.010023))) * -0.0028504)) * -0.01002...
#                                       3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.370e+03
# Progress: 309 / 800 total iterations (38.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₂ + x₅) * 0.010014
# 7           3.221e-08  1.284e-05  y = (x₂ + (x₅ - -1.8144e-05)) * 0.010014
# 9           3.221e-08  9.716e-06  y = (x₂ + ((x₅ - -1.8144e-05) - -1.8144e-05)) * 0.010014
# 11          2.190e-08  1.929e-01  y = ((x₀ * 0.00085928) + (x₅ * 0.010019)) - (x₂ * -0.01001...
#                                       9)
# 13          1.501e-08  1.889e-01  y = ((x₅ * -0.99895) - (x₂ + (x₄ * (x₄ * 0.0038985)))) * -...
#                                       0.010022
# 15          1.243e-08  9.447e-02  y = ((x₅ * -0.99885) + ((((x₄ * x₄) + -1.251) * -0.0042831...
#                                       ) - x₂)) * -0.010023
# 21          1.236e-08  9.015e-04  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + (x₀ - 1.9187))) * -0.0028504)) * -0.010023
# 23          1.236e-08  3.535e-05  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + ((x₀ - 1.9187) + -0.010023))) * -0.0028504)) * -0.01002...
#                                       3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.530e+03
# Progress: 328 / 800 total iterations (41.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₂ + x₅) * 0.010014
# 7           3.221e-08  1.284e-05  y = (x₂ + (x₅ - -1.8144e-05)) * 0.010014
# 9           3.221e-08  9.716e-06  y = (x₂ + ((x₅ - -1.8144e-05) - -1.8144e-05)) * 0.010014
# 11          2.190e-08  1.929e-01  y = ((x₀ * 0.00085928) + (x₅ * 0.010019)) - (x₂ * -0.01001...
#                                       9)
# 13          1.501e-08  1.889e-01  y = ((x₅ * -0.99895) - (x₂ + (x₄ * (x₄ * 0.0038985)))) * -...
#                                       0.010022
# 15          1.241e-08  9.530e-02  y = (((x₅ * -0.99882) - x₂) * -0.010023) + (((x₄ * x₄) + -...
#                                       1.2604) * 4.3692e-05)
# 21          1.236e-08  6.235e-04  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + (x₀ - 1.9187))) * -0.0028504)) * -0.010023
# 23          1.236e-08  3.535e-05  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + ((x₀ - 1.9187) + -0.010023))) * -0.0028504)) * -0.01002...
#                                       3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.540e+03
# Progress: 337 / 800 total iterations (42.125%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₅ + x₂) * 0.010014
# 7           3.221e-08  1.225e-05  y = (x₂ + (x₅ - -1.8144e-05)) * 0.010014
# 9           3.221e-08  9.716e-06  y = (x₂ + ((x₅ - -1.8144e-05) - -1.8144e-05)) * 0.010014
# 11          2.190e-08  1.929e-01  y = ((x₀ * 0.00085928) + (x₅ * 0.010019)) - (x₂ * -0.01001...
#                                       9)
# 13          1.500e-08  1.894e-01  y = ((x₅ * -0.99895) - (x₂ + ((x₄ * x₄) * 0.0038253))) * -...
#                                       0.010022
# 15          1.241e-08  9.482e-02  y = (((x₅ * -0.99882) - x₂) * -0.010023) + (((x₄ * x₄) + -...
#                                       1.2604) * 4.3692e-05)
# 21          1.236e-08  6.235e-04  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + (x₀ - 1.9187))) * -0.0028504)) * -0.010023
# 23          1.236e-08  3.535e-05  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + ((x₀ - 1.9187) + -0.010023))) * -0.0028504)) * -0.01002...
#                                       3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.420e+03
# Progress: 339 / 800 total iterations (42.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₅ + x₂) * 0.010014
# 7           3.221e-08  1.225e-05  y = (x₂ + (x₅ - -1.8144e-05)) * 0.010014
# 9           3.221e-08  9.716e-06  y = (x₂ + ((x₅ - -1.8144e-05) - -1.8144e-05)) * 0.010014
# 11          2.190e-08  1.929e-01  y = ((x₀ * 0.00085928) + (x₅ * 0.010019)) - (x₂ * -0.01001...
#                                       9)
# 13          1.500e-08  1.894e-01  y = ((x₅ * -0.99895) - (x₂ + ((x₄ * x₄) * 0.0038253))) * -...
#                                       0.010022
# 15          1.241e-08  9.482e-02  y = (((x₅ * -0.99882) - x₂) * -0.010023) + (((x₄ * x₄) + -...
#                                       1.2604) * 4.3692e-05)
# 21          1.236e-08  6.235e-04  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + (x₀ - 1.9187))) * -0.0028504)) * -0.010023
# 23          1.236e-08  3.535e-05  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        + ((x₀ - 1.9187) + -0.010023))) * -0.0028504)) * -0.01002...
#                                       3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.210e+03
# Progress: 364 / 800 total iterations (45.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₅ + x₂) * 0.010014
# 7           3.221e-08  1.225e-05  y = (x₂ + (x₅ - -1.8144e-05)) * 0.010014
# 9           3.221e-08  9.716e-06  y = (x₂ + ((x₅ - -1.8144e-05) - -1.8144e-05)) * 0.010014
# 11          2.190e-08  1.929e-01  y = ((x₀ * 0.00085928) + (x₅ * 0.010019)) - (x₂ * -0.01001...
#                                       9)
# 13          1.500e-08  1.894e-01  y = ((x₅ * -0.99895) - (x₂ + ((x₄ * x₄) * 0.0038253))) * -...
#                                       0.010022
# 15          1.241e-08  9.482e-02  y = (((x₅ * -0.99882) - x₂) * -0.010023) + (((x₄ * x₄) + -...
#                                       1.2604) * 4.3692e-05)
# 19          1.239e-08  3.409e-04  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        - 1.9187)) * -0.0028504)) * -0.010023
# 21          1.236e-08  1.189e-03  y = ((((((x₀ + x₀) - 1.9187) + ((x₄ * x₄) * 1.4859)) * -0....
#                                       0028504) + (x₅ * -0.99885)) - x₂) * -0.010023
# 23          1.236e-08  1.081e-04  y = ((((((x₀ + (x₀ - 1.9187)) + -0.055601) + ((x₄ * x₄) * ...
#                                       1.4859)) * -0.0028504) + (x₅ * -0.99885)) - x₂) * -0.01002...
#                                       3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.140e+03
# Progress: 367 / 800 total iterations (45.875%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₅ + x₂) * 0.010014
# 7           3.221e-08  1.380e-05  y = ((x₅ + x₂) - -3.6287e-05) * 0.010014
# 9           3.221e-08  8.166e-06  y = (x₂ + ((x₅ - -1.8144e-05) - -1.8144e-05)) * 0.010014
# 11          2.190e-08  1.929e-01  y = ((x₀ * 0.00085928) + (x₅ * 0.010019)) - (x₂ * -0.01001...
#                                       9)
# 13          1.500e-08  1.894e-01  y = ((x₅ * -0.99895) - (x₂ + ((x₄ * x₄) * 0.0038253))) * -...
#                                       0.010022
# 15          1.241e-08  9.482e-02  y = (((x₅ * -0.99882) - x₂) * -0.010023) + (((x₄ * x₄) + -...
#                                       1.2604) * 4.3692e-05)
# 19          1.239e-08  3.409e-04  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        - 1.9187)) * -0.0028504)) * -0.010023
# 21          1.236e-08  1.189e-03  y = ((((((x₀ + x₀) - 1.9187) + ((x₄ * x₄) * 1.4859)) * -0....
#                                       0028504) + (x₅ * -0.99885)) - x₂) * -0.010023
# 23          1.236e-08  1.081e-04  y = ((((((x₀ + (x₀ - 1.9187)) + -0.055601) + ((x₄ * x₄) * ...
#                                       1.4859)) * -0.0028504) + (x₅ * -0.99885)) - x₂) * -0.01002...
#                                       3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.970e+03
# Progress: 370 / 800 total iterations (46.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₅ + x₂) * 0.010014
# 7           3.221e-08  1.380e-05  y = ((x₅ + x₂) - -3.6287e-05) * 0.010014
# 9           3.221e-08  8.166e-06  y = (x₂ + ((x₅ - -1.8144e-05) - -1.8144e-05)) * 0.010014
# 11          2.190e-08  1.929e-01  y = ((x₀ * 0.00085928) + (x₅ * 0.010019)) - (x₂ * -0.01001...
#                                       9)
# 13          1.500e-08  1.894e-01  y = ((x₅ * -0.99895) - (x₂ + ((x₄ * x₄) * 0.0038253))) * -...
#                                       0.010022
# 15          1.241e-08  9.482e-02  y = (((x₅ * -0.99882) - x₂) * -0.010023) + (((x₄ * x₄) + -...
#                                       1.2604) * 4.3692e-05)
# 19          1.239e-08  3.409e-04  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        - 1.9187)) * -0.0028504)) * -0.010023
# 21          1.236e-08  1.189e-03  y = ((((((x₀ + x₀) - 1.9187) + ((x₄ * x₄) * 1.4859)) * -0....
#                                       0028504) + (x₅ * -0.99885)) - x₂) * -0.010023
# 23          1.236e-08  1.081e-04  y = ((((((x₀ + (x₀ - 1.9187)) + -0.055601) + ((x₄ * x₄) * ...
#                                       1.4859)) * -0.0028504) + (x₅ * -0.99885)) - x₂) * -0.01002...
#                                       3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.560e+03
# Progress: 389 / 800 total iterations (48.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₅ + x₂) * 0.010014
# 7           3.221e-08  1.380e-05  y = ((x₅ + x₂) - -3.6287e-05) * 0.010014
# 9           3.221e-08  8.166e-06  y = (x₂ + ((x₅ - -1.8144e-05) - -1.8144e-05)) * 0.010014
# 11          2.190e-08  1.929e-01  y = ((x₀ * 0.00085928) + (x₅ * 0.010019)) - (x₂ * -0.01001...
#                                       9)
# 13          1.500e-08  1.894e-01  y = ((x₅ * -0.99895) - (x₂ + ((x₄ * x₄) * 0.0038253))) * -...
#                                       0.010022
# 15          1.241e-08  9.482e-02  y = (((x₅ * -0.99882) - x₂) * -0.010023) + (((x₄ * x₄) + -...
#                                       1.2604) * 4.3692e-05)
# 19          1.239e-08  3.409e-04  y = (((x₅ * -0.99885) - x₂) + (((x₄ * (x₄ * 1.4859)) + (x₀...
#                                        - 1.9187)) * -0.0028504)) * -0.010023
# 21          1.236e-08  1.189e-03  y = ((((((x₀ + x₀) - 1.9187) + ((x₄ * x₄) * 1.4859)) * -0....
#                                       0028504) + (x₅ * -0.99885)) - x₂) * -0.010023
# ...
# 9           3.221e-08  1.076e-05  y = (((x₂ + x₅) - -3.6287e-05) - -3.6287e-05) * 0.010014
# 11          2.190e-08  1.929e-01  y = (x₅ * 0.010019) + (((x₀ * -0.085737) - x₂) * -0.010019...
#                                       )
# 13          1.499e-08  1.895e-01  y = ((x₅ * -0.99897) - (x₂ + (x₄ * (x₄ * 0.0038073)))) * -...
#                                       0.010022
# 15          1.240e-08  9.470e-02  y = (((x₄ * x₄) + -1.2504) * 4.3692e-05) + (((x₅ * -0.9988...
#                                       2) - x₂) * -0.010023)
# 17          1.240e-08  1.833e-05  y = ((((x₅ * -0.99882) - x₂) * -0.010023) + (((x₄ * -0.094...
#                                       336) * x₄) * -0.00046287)) - 5.455e-05
# 19          1.237e-08  1.338e-03  y = (2.8941e-05 * ((1.4859 * ((x₄ * x₄) + x₀)) - 1.9187)) ...
#                                       + (-0.010023 * ((x₅ * -0.99884) - x₂))
# 21          7.607e-09  2.432e-01  y = (((((0.013832 - x₀) - ((-0.00020186 * (x₂ + x₂)) * x₅)...
#                                       ) * 0.087353) - x₂) * -0.01001) + (0.01001 * x₅)
# 23          7.238e-09  2.488e-02  y = (((((0.013832 - x₀) - (((x₅ * -0.00020186) * (x₂ + x₂)...
#                                       ) + -0.022713)) * 0.087353) - x₂) * -0.01001) + (x₅ * 0.01...
#                                       001)
# 25          7.024e-09  1.501e-02  y = (x₅ * 0.01001) + ((((0.012574 - ((x₀ - (((x₅ * 0.00017...
#                                       972) * (x₂ + x₂)) + 0.020887)) * 0.097084)) - x₂) * -0.010...
#                                       01) - -0.00010686)
# 27          5.979e-09  8.054e-02  y = (x₅ * 0.010004) + ((((((x₀ - ((((2.7303 - x₂) + (x₅ * ...
#                                       -0.90206)) + 2.9805) * -0.0091015)) * x₀) - x₀) * 0.20526)...
#                                        - x₂) * -0.010003)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.420e+03
# Progress: 771 / 800 total iterations (96.375%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₅ + x₂) * 0.010014
# 7           3.221e-08  1.380e-05  y = ((x₅ + x₂) - -3.6287e-05) * 0.010014
# 9           3.221e-08  1.076e-05  y = (((x₂ + x₅) - -3.6287e-05) - -3.6287e-05) * 0.010014
# 11          2.190e-08  1.929e-01  y = (x₅ * 0.010019) + (((x₀ * -0.085737) - x₂) * -0.010019...
#                                       )
# 13          1.499e-08  1.895e-01  y = ((x₅ * -0.99897) - (x₂ + (x₄ * (x₄ * 0.0038073)))) * -...
#                                       0.010022
# 15          1.240e-08  9.470e-02  y = (((x₄ * x₄) + -1.2504) * 4.3692e-05) + (((x₅ * -0.9988...
#                                       2) - x₂) * -0.010023)
# 17          1.240e-08  1.833e-05  y = ((((x₅ * -0.99882) - x₂) * -0.010023) + (((x₄ * -0.094...
#                                       336) * x₄) * -0.00046287)) - 5.455e-05
# 19          1.237e-08  1.338e-03  y = (2.8941e-05 * ((1.4859 * ((x₄ * x₄) + x₀)) - 1.9187)) ...
#                                       + (-0.010023 * ((x₅ * -0.99884) - x₂))
# 21          7.607e-09  2.432e-01  y = (((((0.013832 - x₀) - ((-0.00020186 * (x₂ + x₂)) * x₅)...
#                                       ) * 0.087353) - x₂) * -0.01001) + (0.01001 * x₅)
# 23          7.238e-09  2.488e-02  y = (((((0.013832 - x₀) - (((x₅ * -0.00020186) * (x₂ + x₂)...
#                                       ) + -0.022713)) * 0.087353) - x₂) * -0.01001) + (x₅ * 0.01...
#                                       001)
# 25          7.024e-09  1.501e-02  y = (x₅ * 0.01001) + ((((0.012574 - ((x₀ - (((x₅ * 0.00017...
#                                       972) * (x₂ + x₂)) + 0.020887)) * 0.097084)) - x₂) * -0.010...
#                                       01) - -0.00010686)
# 27          5.979e-09  8.054e-02  y = (x₅ * 0.010004) + ((((((x₀ - ((((2.7303 - x₂) + (x₅ * ...
#                                       -0.90206)) + 2.9805) * -0.0091015)) * x₀) - x₀) * 0.20526)...
#                                        - x₂) * -0.010003)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.430e+03
# Progress: 773 / 800 total iterations (96.625%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₅ + x₂) * 0.010014
# 7           3.221e-08  1.380e-05  y = ((x₅ + x₂) - -3.6287e-05) * 0.010014
# 9           3.221e-08  1.076e-05  y = (((x₂ + x₅) - -3.6287e-05) - -3.6287e-05) * 0.010014
# 11          2.190e-08  1.929e-01  y = (x₅ * 0.010019) + (((x₀ * -0.085737) - x₂) * -0.010019...
#                                       )
# 13          1.499e-08  1.895e-01  y = ((x₅ * -0.99897) - (x₂ + (x₄ * (x₄ * 0.0038073)))) * -...
#                                       0.010022
# 15          1.240e-08  9.470e-02  y = (((x₄ * x₄) + -1.2504) * 4.3692e-05) + (((x₅ * -0.9988...
#                                       2) - x₂) * -0.010023)
# 17          1.240e-08  1.833e-05  y = ((((x₅ * -0.99882) - x₂) * -0.010023) + (((x₄ * -0.094...
#                                       336) * x₄) * -0.00046287)) - 5.455e-05
# 19          1.237e-08  1.338e-03  y = (2.8941e-05 * ((1.4859 * ((x₄ * x₄) + x₀)) - 1.9187)) ...
#                                       + (-0.010023 * ((x₅ * -0.99884) - x₂))
# 21          7.607e-09  2.432e-01  y = (((((0.013832 - x₀) - ((-0.00020186 * (x₂ + x₂)) * x₅)...
#                                       ) * 0.087353) - x₂) * -0.01001) + (0.01001 * x₅)
# 23          7.238e-09  2.488e-02  y = (((((0.013832 - x₀) - (((x₅ * -0.00020186) * (x₂ + x₂)...
#                                       ) + -0.022713)) * 0.087353) - x₂) * -0.01001) + (x₅ * 0.01...
#                                       001)
# 25          7.024e-09  1.501e-02  y = (x₅ * 0.01001) + ((((0.012574 - ((x₀ - (((x₅ * 0.00017...
#                                       972) * (x₂ + x₂)) + 0.020887)) * 0.097084)) - x₂) * -0.010...
#                                       01) - -0.00010686)
# 27          5.979e-09  8.054e-02  y = (x₅ * 0.010004) + ((((((x₀ - ((((2.7303 - x₂) + (x₅ * ...
#                                       -0.90206)) + 2.9805) * -0.0091015)) * x₀) - x₀) * 0.20526)...
#                                        - x₂) * -0.010003)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.480e+03
# Progress: 788 / 800 total iterations (98.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₅ + x₂) * 0.010014
# 7           3.221e-08  1.380e-05  y = ((x₅ + x₂) - -3.6287e-05) * 0.010014
# 9           3.221e-08  1.076e-05  y = (((x₂ + x₅) - -3.6287e-05) - -3.6287e-05) * 0.010014
# 11          2.190e-08  1.929e-01  y = (x₅ * 0.010019) + (((x₀ * -0.085737) - x₂) * -0.010019...
#                                       )
# 13          1.499e-08  1.895e-01  y = ((x₅ * -0.99897) - (x₂ + (x₄ * (x₄ * 0.0038073)))) * -...
#                                       0.010022
# 15          1.240e-08  9.472e-02  y = ((((x₅ * -0.99882) - x₂) * -0.010023) + (x₄ * (x₄ * 4....
#                                       3679e-05))) - 5.455e-05
# 19          1.237e-08  6.688e-04  y = (2.8941e-05 * ((1.4859 * ((x₄ * x₄) + x₀)) - 1.9187)) ...
#                                       + (-0.010023 * ((x₅ * -0.99884) - x₂))
# 21          7.607e-09  2.432e-01  y = (((((0.013832 - x₀) - ((-0.00020186 * (x₂ + x₂)) * x₅)...
#                                       ) * 0.087353) - x₂) * -0.01001) + (0.01001 * x₅)
# 23          7.171e-09  2.955e-02  y = ((0.007906 * x₅) + (((((0.039247 - x₀) - (((x₂ + x₂) *...
#                                        x₅) * -0.00018722)) * 0.087353) - x₂) * -0.007906)) * 1.2...
#                                       662
# 25          7.024e-09  1.034e-02  y = (x₅ * 0.01001) + ((((0.012574 - ((x₀ - (((x₅ * 0.00017...
#                                       972) * (x₂ + x₂)) + 0.020887)) * 0.097084)) - x₂) * -0.010...
#                                       01) - -0.00010686)
# 27          5.979e-09  8.054e-02  y = (x₅ * 0.010004) + ((((((x₀ - ((((2.7303 - x₂) + (x₅ * ...
#                                       -0.90206)) + 2.9805) * -0.0091015)) * x₀) - x₀) * 0.20526)...
#                                        - x₂) * -0.010003)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.390e+03
# Progress: 792 / 800 total iterations (99.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₅ + x₂) * 0.010014
# 7           3.221e-08  1.380e-05  y = ((x₅ + x₂) - -3.6287e-05) * 0.010014
# 9           3.221e-08  1.076e-05  y = (((x₂ + x₅) - -3.6287e-05) - -3.6287e-05) * 0.010014
# 11          2.190e-08  1.929e-01  y = (x₅ * 0.010019) + (((x₀ * -0.085737) - x₂) * -0.010019...
#                                       )
# 13          1.499e-08  1.895e-01  y = ((x₅ * -0.99897) - (x₂ + (x₄ * (x₄ * 0.0038073)))) * -...
#                                       0.010022
# 15          1.240e-08  9.472e-02  y = ((((x₅ * -0.99882) - x₂) * -0.010023) + (x₄ * (x₄ * 4....
#                                       3679e-05))) - 5.455e-05
# 19          1.237e-08  6.688e-04  y = (2.8941e-05 * ((1.4859 * ((x₄ * x₄) + x₀)) - 1.9187)) ...
#                                       + (-0.010023 * ((x₅ * -0.99884) - x₂))
# 21          7.607e-09  2.432e-01  y = (((((0.013832 - x₀) - ((-0.00020186 * (x₂ + x₂)) * x₅)...
#                                       ) * 0.087353) - x₂) * -0.01001) + (0.01001 * x₅)
# 23          7.171e-09  2.955e-02  y = ((0.007906 * x₅) + (((((0.039247 - x₀) - (((x₂ + x₂) *...
#                                        x₅) * -0.00018722)) * 0.087353) - x₂) * -0.007906)) * 1.2...
#                                       662
# 25          7.024e-09  1.034e-02  y = (x₅ * 0.01001) + ((((0.012574 - ((x₀ - (((x₅ * 0.00017...
#                                       972) * (x₂ + x₂)) + 0.020887)) * 0.097084)) - x₂) * -0.010...
#                                       01) - -0.00010686)
# 27          5.979e-09  8.054e-02  y = (x₅ * 0.010004) + ((((((x₀ - ((((2.7303 - x₂) + (x₅ * ...
#                                       -0.90206)) + 2.9805) * -0.0091015)) * x₀) - x₀) * 0.20526)...
#                                        - x₂) * -0.010003)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.813e-02  0.000e+00  y = 1.2779e-05
# 3           1.600e-02  5.508e-01  y = x₅ * 0.013372
# 5           3.221e-08  6.558e+00  y = (x₅ + x₂) * 0.010014
# 7           3.221e-08  1.380e-05  y = ((x₅ + x₂) - -3.6287e-05) * 0.010014
# 9           3.221e-08  1.076e-05  y = (((x₂ + x₅) - -3.6287e-05) - -3.6287e-05) * 0.010014
# 11          2.190e-08  1.929e-01  y = (x₅ * 0.010019) + (((x₀ * -0.085737) - x₂) * -0.010019...
#                                       )
# 13          1.499e-08  1.895e-01  y = ((x₄ * 3.7965e-05) * x₄) + (((x₅ * -0.99898) - x₂) * -...
#                                       0.010022)
# 15          1.240e-08  9.471e-02  y = ((((x₅ * -0.99882) - x₂) * -0.010023) + (x₄ * (x₄ * 4....
#                                       3679e-05))) - 5.455e-05
# 19          1.237e-08  6.688e-04  y = (2.8941e-05 * ((1.4859 * ((x₄ * x₄) + x₀)) - 1.9187)) ...
#                                       + (-0.010023 * ((x₅ * -0.99884) - x₂))
# 21          7.607e-09  2.432e-01  y = (((((0.013832 - x₀) - ((-0.00020186 * (x₂ + x₂)) * x₅)...
#                                       ) * 0.087353) - x₂) * -0.01001) + (0.01001 * x₅)
# 23          7.171e-09  2.955e-02  y = ((0.007906 * x₅) + (((((0.039247 - x₀) - (((x₂ + x₂) *...
#                                        x₅) * -0.00018722)) * 0.087353) - x₂) * -0.007906)) * 1.2...
#                                       662
# 25          6.906e-09  1.878e-02  y = ((x₅ * 0.010012) + (((0.013991 - ((x₀ - (((x₂ + x₂) * ...
#                                       (x₅ * 0.00015056)) + 0.023973)) * 0.10659)) - x₂) * -0.010...
#                                       012)) - -0.00012079
# 27          5.979e-09  7.210e-02  y = (x₅ * 0.010004) + ((((((x₀ - ((((2.7303 - x₂) + (x₅ * ...
#                                       -0.90206)) + 2.9805) * -0.0091015)) * x₀) - x₀) * 0.20526)...
#                                        - x₂) * -0.010003)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs\20250928_213654_TdgXoC\hall_of_fame.csv
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                       1.2779228e-5
# 	1         0.550772                                   x5 * 0.013371806
# 	2         6.557757                            (x5 + x2) * 0.010014186
# 	3         0.000014           ((x5 + x2) - -3.628745e-5) * 0.010014187
# 	4         0.000011  (((x2 + x5) - -3.628745e-5) - -3.628745e-5) * ...
# 	5         0.192889  (x5 * 0.010018738) + (((x0 * -0.0857366) - x2)...
# 	6         0.189530  ((x4 * 3.796528e-5) * x4) + (((x5 * -0.9989769...
# 	7         0.094706  ((((x5 * -0.99882424) - x2) * -0.010022977) + ...
# 	8         0.000669  (2.8941326e-5 * ((1.4858526 * ((x4 * x4) + x0)...
# 	9   >>>>  0.243152  (((((0.0138321705 - x0) - ((-0.0002018594 * (x...
# 	10        0.029548  ((0.007906012 * x5) + (((((0.03924705 - x0) - ...
# 	11        0.018776  ((x5 * 0.0100115435) + (((0.013990633 - ((x0 -...
# 	12        0.072102  (x5 * 0.0100038415) + ((((((x0 - ((((2.7303169...
#
# 	            loss  complexity
# 	0   4.812957e-02           1
# 	1   1.599622e-02           3
# 	2   3.221232e-08           5
# 	3   3.221143e-08           7
# 	4   3.221074e-08           9
# 	5   2.190079e-08          11
# 	6   1.499120e-08          13
# 	7   1.240441e-08          15
# 	8   1.237127e-08          19
# 	9   7.607031e-09          21
# 	10  7.170517e-09          23
# 	11  6.906248e-09          25
# 	12  5.978815e-09          27
# ]

# %%
print(model.equations_)
# Out:
#     complexity          loss  \
# 0            1  4.812957e-02
# 1            3  1.599622e-02
# 2            5  3.221232e-08
# 3            7  3.221143e-08
# 4            9  3.221074e-08
# 5           11  2.190079e-08
# 6           13  1.499120e-08
# 7           15  1.240441e-08
# 8           19  1.237127e-08
# 9           21  7.607031e-09
# 10          23  7.170517e-09
# 11          25  6.906248e-09
# 12          27  5.978815e-09
#
#                                              equation     score  \
# 0                                        1.2779228e-5  0.000000
# 1                                    x5 * 0.013371806  0.550772
# 2                             (x5 + x2) * 0.010014186  6.557757
# 3            ((x5 + x2) - -3.628745e-5) * 0.010014187  0.000014
# 4   (((x2 + x5) - -3.628745e-5) - -3.628745e-5) * ...  0.000011
# 5   (x5 * 0.010018738) + (((x0 * -0.0857366) - x2)...  0.192889
# 6   ((x4 * 3.796528e-5) * x4) + (((x5 * -0.9989769...  0.189530
# 7   ((((x5 * -0.99882424) - x2) * -0.010022977) + ...  0.094706
# 8   (2.8941326e-5 * ((1.4858526 * ((x4 * x4) + x0)...  0.000669
# 9   (((((0.0138321705 - x0) - ((-0.0002018594 * (x...  0.243152
# 10  ((0.007906012 * x5) + (((((0.03924705 - x0) - ...  0.029548
# 11  ((x5 * 0.0100115435) + (((0.013990633 - ((x0 -...  0.018776
# 12  (x5 * 0.0100038415) + ((((((x0 - ((((2.7303169...  0.072102
#
#                                          sympy_format  \
# 0                                 1.27792280000000e-5
# 1                                      x5*0.013371806
# 2                               (x2 + x5)*0.010014186
# 3            (x2 + x5 - 1*(-3.628745e-5))*0.010014187
# 4   (x2 + x5 - 1*(-3.628745e-5) - 1*(-3.628745e-5)...
# 5   x5*0.010018738 + (x0*(-0.0857366) - x2)*(-0.01...
# 6   x4*3.796528e-5*x4 + (-x2 + x5*(-0.9989769))*(-...
# 7   x4*x4*4.3678523e-5 + (-x2 + x5*(-0.99882424))*...
# 8   -0.010022979*(-x2 + x5*(-0.9988422)) + 2.89413...
# 9   0.010009706*x5 + (-x2 + (-x0 - (-1)*0.00020185...
# 10  (0.007906012*x5 + (-x2 + (-x0 - (-0.0001872230...
# 11  x5*0.0100115435 + (-x2 - 0.1065873*(x0 - ((x2 ...
# 12  x5*0.0100038415 + (-x2 + (x0*(x0 - (-0.0091015...
#
#                                         lambda_format
# 0              PySRFunction(X=>0.0000127792280000000)
# 1                     PySRFunction(X=>x5*0.013371806)
# 2              PySRFunction(X=>(x2 + x5)*0.010014186)
# 3   PySRFunction(X=>(x2 + x5 - 1*(-3.628745e-5))*0...
# 4   PySRFunction(X=>(x2 + x5 - 1*(-3.628745e-5) - ...
# 5   PySRFunction(X=>x5*0.010018738 + (x0*(-0.08573...
# 6   PySRFunction(X=>x4*3.796528e-5*x4 + (-x2 + x5*...
# 7   PySRFunction(X=>x4*x4*4.3678523e-5 + (-x2 + x5...
# 8   PySRFunction(X=>-0.010022979*(-x2 + x5*(-0.998...
# 9   PySRFunction(X=>0.010009706*x5 + (-x2 + (-x0 -...
# 10  PySRFunction(X=>(0.007906012*x5 + (-x2 + (-x0 ...
# 11  PySRFunction(X=>x5*0.0100115435 + (-x2 - 0.106...
# 12  PySRFunction(X=>x5*0.0100038415 + (-x2 + (x0*(...
